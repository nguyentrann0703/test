# %%
from ydata_profiling import ProfileReport
ProfileReport(movies,title = "Data Report").to_file('report.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from ydata_profiling import ProfileReport
# ----> 2 ProfileReport(movies,title = "Data Report").to_file('report.html')
#
# NameError: name 'movies' is not defined

# %%
import pandas as pd

# %% [markdown]
# # REV STOP

# %%
rev_stop = pd.read_csv('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/HCMC_bus_routes/1/rev_stops_by_var.csv',delimiter= ',')

# %%
rev_stop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StopId             33 non-null     int64
#  1   Code               33 non-null     object
#  2   Name               33 non-null     object
#  3   StopType           33 non-null     object
#  4   Zone               33 non-null     object
#  5   Ward               9 non-null      object
#  6   AddressNo          33 non-null     object
#  7   Street             33 non-null     object
#  8   SupportDisability  2 non-null      object
#  9   Status             33 non-null     object
#  10  Lng                33 non-null     float64
#  11  Lat                33 non-null     float64
#  12  Search             33 non-null     object
#  13  Routes             33 non-null     object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
rev_stop.head()
# Out:
#    StopId    Code                 Name  StopType    Zone Ward  \
# 0       8    BX14  Bến xe buýt Chợ Lớn    Bến xe  Quận 5  NaN
# 1    2393  Q6 096            Tháp Mười  Trụ dừng  Quận 6  NaN
# 2       2  Q5 016         Chợ Kim Biên  Trụ dừng  Quận 5  NaN
# 3       3  Q5 011      Bưu điện Quận 5     Ô sơn  Quận 5  NaN
# 4       5  Q5 012        Rạp Đại Quang   Nhà chờ  Quận 5  NaN
#
#          AddressNo              Street SupportDisability          Status  \
# 0  GA HKXB CHO LON       Lê Quang Sung               NaN  Đang khai thác
# 1          13C-13D           Tháp Mười               NaN  Đang khai thác
# 2            11-12  Hải Thượng Lãn Ông               NaN  Đang khai thác
# 3            14-16       Châu Văn Liêm               NaN  Đang khai thác
# 4               68       Châu Văn Liêm               NaN  Đang khai thác
#
#           Lng        Lat          Search  \
# 0  106.652565  10.751253  BxbCL GHCL LQS
# 1  106.653036  10.750326   TM 13C-13D TM
# ...

# %%
rev_stop.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 rev_stop.info()
#
# NameError: name 'rev_stop' is not defined

# %% [markdown]
# # ROUTE_BY_ID

# %%
route_by_id = pd.read_csv('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/HCMC_bus_routes/1/route_by_id.csv')
route_by_id.head()
# Out:
#    RouteId  RouteNo                        RouteName    Color  \
# 0        1        1  Bến Thành - Bến xe buýt Chợ Lớn  #FFB07C
#
#                      Type  Distance  \
# 0  Phổ thông - Có trợ giá    8590.0
#
#                                                 Orgs  TimeOfTrip  Headway  \
# 0  Công ty TNHH Du lịch, Dịch vụ Xây dựng Bảo Yến...          35  15 - 18
#
#    OperationTime  NumOfSeats          OutBoundName InBoundName  \
# 0  05:00 - 20:15          50  Bến xe buýt Chợ Lớn¿  Bến Thành¿
#
#                                  OutBoundDescription  \
# 0  Công trường Mê Linh - Đường Thi Sách - Công tr...
#
#                                   InBoundDescription  TotalTrip  \
# 0  Bến xe buýt Chợ Lớn (Bến A) - Đường Lê Quang S...  120 [TPD]
#
#                                              Tickets
# 0  <br/>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp- Vé lượt t...

# %% [markdown]
# # STOP_BY_VAR

# %%
stop_by_var = pd.read_csv('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/HCMC_bus_routes/1/stops_by_var.csv')
stop_by_var.head()
# Out:
#    StopId    Code                    Name  StopType    Zone             Ward  \
# 0      33   BX 06     Công Trường Mê Linh    Bến xe  Quận 1  Phường Bến Nghé
# 1      79  Q1 031           Bến Bạch Đằng  Trụ dừng  Quận 1              NaN
# 2      76  Q1 020  Cục Hải Quan Thành Phố   Nhà chờ  Quận 1  Phường Bến Nghé
# 3    3691  Q1 193                  Chợ Cũ   Nhà chờ  Quận 1  Phường Bến Nghé
# 4    2028  Q1 194        Trường Cao Thắng   Nhà chờ  Quận 1  Phường Bến Nghé
#
#              AddressNo         Street  SupportDisability          Status  \
# 0  Công trường Mê Linh       Thi Sách                NaN  Đang khai thác
# 1                   21  Tôn Đức Thắng                NaN  Đang khai thác
# 2                  2-4       Hàm Nghi                NaN  Đang khai thác
# 3                   84       Hàm Nghi                NaN  Đang khai thác
# 4     Trường Cao Thắng       Hàm Nghi                NaN  Đang khai thác
#
#           Lng        Lat        Search  \
# ...

# %%
stop_by_var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StopId             28 non-null     int64
#  1   Code               28 non-null     object
#  2   Name               28 non-null     object
#  3   StopType           28 non-null     object
#  4   Zone               28 non-null     object
#  5   Ward               6 non-null      object
#  6   AddressNo          28 non-null     object
#  7   Street             28 non-null     object
#  8   SupportDisability  0 non-null      float64
#  9   Status             28 non-null     object
#  10  Lng                28 non-null     float64
#  11  Lat                28 non-null     float64
#  12  Search             28 non-null     object
#  13  Routes             28 non-null     object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 3.2+ KB

# %% [markdown]
# # VAR_BY_ROUTE

# %%
var_by_route = pd.read_csv('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/HCMC_bus_routes/1/vars_by_route.csv')
var_by_route.head()
# Out:
#    RouteId  RouteVarId                                       RouteVarName  \
# 0        1           1  Lượt đi: Công Trường Mê Linh - Bến xe buýt Chợ...
# 1        1           2  Lượt về: Bến xe buýt Chợ Lớn - Công Trường Mê ...
#
#      RouteVarShortName  RouteNo            StartStop              EndStop  \
# 0  Bến xe buýt Chợ Lớn        1  Công Trường Mê Linh  Bến xe buýt Chợ Lớn
# 1            Bến Thành        1  Bến xe buýt Chợ Lớn  Công Trường Mê Linh
#
#    Distance  Outbound  RunningTime
# 0    7968.0      True           35
# 1    9189.0     False           35

# %% [markdown]
# # RAW_GPS

# %%
raw_gps = pd.read_csv('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/raw_GPS/anonymized_raw_2025-04-01.csv')
raw_gps.head()
# Out:
#               datetime         lng        lat  speed  door_up  door_down  \
# 0  2025-04-01 00:00:01  106.482285  10.971292    NaN    False      False
# 1  2025-04-01 00:00:10  106.705688  10.694684    NaN    False      False
# 2  2025-04-01 00:00:28  106.512432  10.787085    NaN    False      False
# 3  2025-04-01 00:00:01  106.741605  10.602732    NaN    False      False
# 4  2025-04-01 00:00:01  106.640020  10.769893    NaN    False      False
#
#   anonymized_vehicle anonymized_driver
# 0         f3a3e75584               NaN
# 1         7121f294ef               NaN
# 2         6cd3c92c48               NaN
# 3         f373b0e01d               NaN
# 4         058ff527c8               NaN

# %% [markdown]
# # TIME TABLE 01

# %%
time_table_01 = pd.read_excel('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/Timetable/01_2025-N.xls')
time_table_01.head()
# Out:
#   Phụ lục\n1.1. Tuyến xe buýt có trợ giá số 1: Bến Thành – Bến xe buýt Chợ Lớn\n(Ban hành kèm theo Quyết định số      /QĐ-TT  ngày     /01/2022 của Trung tâm)\n\nBIỂU ĐỒ CHẠY XE\nÁp dụng ngày 31/01/2022   \
# 0                                             Chuyến
# 1                                                NaN
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#                 Unnamed: 1             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                BẾN THÀNH                    NaN        NaN        NaN
# 1  Đi\nCông trường Mê Linh  Đến \nBX buýt Chợ Lớn       time       time
# 2                 05:00:00               05:35:00        NaN        NaN
# 3                 05:30:00               06:05:00   00:30:00   00:30:00
# 4                 06:00:00               06:35:00   00:30:00   00:30:00
#
# ...

# %% [markdown]
# # TIME TABLE 06

# %%
time_table_06 = pd.read_excel('/Users/nguyentran0703/Downloads/BDC HACKATHON/Bus_route_data/Timetable/06_2025-2.xls')
time_table_06.head()
# Out:
#   Phụ lục II\n(Ban hành kèm theo Quyết định số       /QĐ-TT ngày      tháng 4 năm 2021\ncủa Trung tâm Quản lý Giao thông công cộng) \n\n1.1.Tuyến xe buýt có trợ giá số 6: Bến xe buýt Chợ Lớn - Đại học Nông Lâm\nBIỂU ĐỒ CHẠY XE\nThực hiện ngày 21/4/2021 và từ ngày 30/4/2021 đến hết ngày 03/5/2021  \
# 0                                             Chuyến
# 1                                                NaN
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#             Unnamed: 1         Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  Bến xe buýt Chợ Lớn                NaN        NaN        NaN
# 1  Đi\nBX buýt Chợ Lớn  Đến \nĐH Nông Lâm       time       time
# 2             04:55:00           06:05:00        NaN        NaN
# 3             05:15:00           06:25:00   00:20:00   00:20:00
# 4             05:32:00           06:42:00   00:17:00   00:17:00
#
# ...

# %%
route_full = route_by_id.merge(var_by_route, on= "RouteId", how='left')
route_full
# Out:
#    RouteId  RouteNo_x                        RouteName    Color  \
# 0        1          1  Bến Thành - Bến xe buýt Chợ Lớn  #FFB07C
# 1        1          1  Bến Thành - Bến xe buýt Chợ Lớn  #FFB07C
#
#                      Type  Distance_x  \
# 0  Phổ thông - Có trợ giá      8590.0
# 1  Phổ thông - Có trợ giá      8590.0
#
#                                                 Orgs  TimeOfTrip  Headway  \
# 0  Công ty TNHH Du lịch, Dịch vụ Xây dựng Bảo Yến...          35  15 - 18
# 1  Công ty TNHH Du lịch, Dịch vụ Xây dựng Bảo Yến...          35  15 - 18
#
#    OperationTime  ...                                            Tickets  \
# 0  05:00 - 20:15  ...  <br/>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp- Vé lượt t...
# 1  05:00 - 20:15  ...  <br/>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp- Vé lượt t...
#
#   RouteVarId                                       RouteVarName  \
# 0          1  Lượt đi: Công Trường Mê Linh - Bến xe buýt Chợ...
# 1          2  Lượt về: Bến xe buýt Chợ Lớn - Công Trường Mê ...
#
# ...

# %%
stop_full = stop_by_var.merge(var_by_route[["RouteNo", "RouteVarId", "Outbound"]],
                              on="RouteNo",
                              how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nx/tm25jbz54jjdb9mb8c28s0m00000gn/T/ipykernel_11010/3169279708.py in ?()
# ----> 1 stop_full = stop_by_var.merge(var_by_route[["RouteNo", "RouteVarId", "Outbound"]],
#       2                               on="RouteNo",
#       3                               how="left")
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10835         validate: MergeValidate | None = None,
#   10836     ) -> DataFrame:
#   10837         from pandas.core.reshape.merge import merge
#   10838
# > 10839         return merge(
#   10840             self,
#   10841             right,
#   10842             how=how,
#
# ...

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371000  # meters
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    return R * 2 * atan2(sqrt(a), sqrt(1-a))

# ===========================================================
# 3. FILTER STOP BY ROUTE (ROUTES CONTAINS ROUTENO)
# ===========================================================

ROUTE_NO = "01"

stop_route = stop[stop["Routes"].str.contains(ROUTE_NO)]

# ===========================================================
# 4. ASSIGN STOP TO ROUTEVAR (OUTBOUND / INBOUND)
# ===========================================================

# Lấy 2 biến thể tuyến
rv_out = routevar[(routevar.RouteNo == int(ROUTE_NO)) & (routevar.Outbound == True)].iloc[0]
rv_in  = routevar[(routevar.RouteNo == int(ROUTE_NO)) & (routevar.Outbound == False)].iloc[0]

# Tìm vị trí start stop của từng chiều
def find_stop_coordinates(stop_name, stop_table):
    row = stop_table[stop_table["Name"] == stop_name]
    if row.empty:
        return None, None
    return float(row.Lat), float(row.Lng)

out_lat, out_lng = find_stop_coordinates(rv_out.StartStop, stop_route)
in_lat, in_lng   = find_stop_coordinates(rv_in.StartStop, stop_route)

def assign_routevar(row):
    d_out = haversine(row.Lat, row.Lng, out_lat, out_lng)
    d_in  = haversine(row.Lat, row.Lng, in_lat, in_lng)
    return rv_out.RouteVarId if d_out < d_in else rv_in.RouteVarId

stop_route["RouteVarId"] = stop_route.apply(assign_routevar, axis=1)

# ===========================================================
# 5. CLEAN GPS
# ===========================================================

gps["datetime"] = pd.to_datetime(gps["datetime"])
gps = gps.sort_values(["anonymized_vehicle", "datetime"])
gps["date"] = gps["datetime"].dt.date

# ===========================================================
# 6. MAP GPS TO STOP (NEAR STOP + LOW SPEED)
# ===========================================================

def find_closest_stop(gps_row, stops):
    min_dist = 999999
    matched_stop = None
    
    for _, st in stops.iterrows():
        d = haversine(gps_row.lat, gps_row.lng, st.Lat, st.Lng)
        if d < min_dist:
            min_dist = d
            matched_stop = st.StopId
            
    if min_dist < 30:    # 30m radius
        return matched_stop
    return np.nan

gps["StopId"] = gps.apply(lambda r: find_closest_stop(r, stop_route), axis=1)

gps_stop = gps[gps["StopId"].notna()]

# ===========================================================
# 7. DETECT TRIPS USING DOOR & PROXIMITY
# ===========================================================

def detect_trips(data):
    trips = []
    current_trip = None
    
    for idx, row in data.iterrows():
        if row.door_down and current_trip is None:
            current_trip = {
                "Vehicle": row.anonymized_vehicle,
                "StartTime": row.datetime
            }
        if row.door_down and current_trip is not None:
            current_trip["EndTime"] = row.datetime
    
    if current_trip:
        trips.append(current_trip)
    return trips

all_trips = []

for vehicle, df in gps.groupby("anonymized_vehicle"):
    df = df.sort_values("datetime")
    all_trips += detect_trips(df)

real_trip = pd.DataFrame(all_trips)
real_trip["Duration_min"] = (real_trip.EndTime - real_trip.StartTime).dt.total_seconds() / 60

# ===========================================================
# 8. COMPUTE FREQUENCY PER ROUTE
# ===========================================================

real_trip["hour"] = real_trip.StartTime.dt.hour

frequency = real_trip.groupby("hour").size().reset_index(name="trips_per_hour")

# ===========================================================
# 9. PASSENGER DENSITY (PROXY)
# ===========================================================

# số lần mở cửa tại stop = proxy lượt lên xuống khách
passenger_density = gps_stop.groupby("StopId")["door_down"].sum().reset_index()
passenger_density.columns = ["StopId", "PassengerScore"]

# thêm thông tin stop
passenger_density = passenger_density.merge(stop_route[["StopId", "Name", "Lat", "Lng"]],
                                            on="StopId",
                                            how="left")

# ===========================================================
# 10. OUTPUT RESULTS
# ===========================================================

print("=== FREQUENCY TABLE (TRIPS PER HOUR) ===")
print(frequency)

print("\n=== PASSENGER DENSITY (PROXY FROM DOOR OPEN) ===")
print(passenger_density.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 15
#       9 # ===========================================================
#      10 # 3. FILTER STOP BY ROUTE (ROUTES CONTAINS ROUTENO)
#      11 # ===========================================================
#      13 ROUTE_NO = "01"
# ---> 15 stop_route = stop[stop["Routes"].str.contains(ROUTE_NO)]
#      17 # ===========================================================
#      18 # 4. ASSIGN STOP TO ROUTEVAR (OUTBOUND / INBOUND)
#      19 # ===========================================================
#      20
#      21 # Lấy 2 biến thể tuyến
#      22 rv_out = routevar[(routevar.RouteNo == int(ROUTE_NO)) & (routevar.Outbound == True)].iloc[0]
#
# NameError: name 'stop' is not defined
